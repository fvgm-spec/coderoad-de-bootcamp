# %% [markdown]
# <a href="https://colab.research.google.com/github/fvgm-spec/coderoad-de-bootcamp/blob/main/000_test_drive_connection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Connect Google Drive

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Load file with pandas

# %%
import pandas as pd

# %%
products = pd.read_csv("/content/drive/MyDrive/renan_coderoad_databootcamp_2025/data/PRODUCTS.csv")
products
# Out:
#                 gtin  categoryParent  colorLabel modelLabel  \
# 0       713610167277        960-SWIM         112   CUKFA048
# 1       713610167277        960-SWIM         112   CUKFA048
# 2       795570651201      742-SHORTS         429   4DSH7750
# 3       795570651201      742-SHORTS         429   4DSH7750
# 4       795570651201      742-SHORTS         429   4DSH7750
# ...              ...             ...         ...        ...
# 124177  795570027945   780-OUTERWEAR          10   4FHR7701
# 124178  795570027945   780-OUTERWEAR          10   4FHR7701
# 124179  795570027945   780-OUTERWEAR          10   4FHR7701
# 124180  795570254006  733-COLLECTION         405   EGFW9002
# 124181  795570254006  733-COLLECTION         405   EGFW9002
#
#                                          productLabelLong sizeLabel  \
# 0       SS T/C SLUB V-NECK  T-SHIRT - BRILLIANT WHITE ...       XXL
# 1       SS T/C SLUB V-NECK  T-SHIRT - BRILLIANT WHITE ...       XXL
# ...
